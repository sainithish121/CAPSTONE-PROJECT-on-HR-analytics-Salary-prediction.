# %% [markdown]
# **CAPSTONE PROJECT ON HR-INDUSTRY**
#
# Solving this problem will help you to gain a basic understanding of the HR industry and also how analytics and data science are applied in practice in this domain.
#
# **A brief understanding of the HR industry**
#
# Human resources (HR) is the division of an organization that is responsible for finding, screening, recruiting, and training job applicants, and administering employee-benefit programs.
#
# This management is the strategic approach to the efficient management of people in any organization in a way that can help their business gain a competitive advantage. It is designed to improve employee performance in service of an employer's strategic objectives.
#
# **Understanding the Problem Statement**
#
# In this project, you will have to put yourself in the shoes of an HR analytics expert and by leveraging the data provided, you are supposed to identify how salary is varying with respect to other considerable factors.
#
# The dataset should be divided into test and train and you would have to use the training data to build the model and thereby apply it to test data to measure the performance and robustness of the model.
#
# **ABOUT THE DATASET**
#
# Here the dataset is about the employees and their information in detail like gender ,age ,salary,education etc
# It is having 20 features related to employee
# And our agenda is to show salary is varying with respect to other considerable factors.

# %% [markdown]
# ##**Problem Statement:**
# #  **how salary is varying with respect to other considerable factors.**

# %% [markdown]
# **We have Human resources(HR) organization dataset. There are 5000 rows and  20 columns within the dataset**

# %% [markdown]
# ##**Data Analysis and Interpretations**

# %%
#importing neccessary libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import  seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#reading the dataset with na_values function to replace empty place with nan value
# hr_data=pd.read_csv("New_data_Set.csv",na_values=" ")

hr_data=pd.read_csv("/content/New_data_Set.csv",na_values=" ")

# %% [markdown]
# **There are some empty spaces in Total_sales. So we can replace those with nan**

# %%
#To know the shape of our data
hr_data.shape
# Out:
# (5000, 20)

# %% [markdown]
# **There are 5000 rows and 20 columns wthin the dataset**

# %%
#using head function to get first 5rows of data
hr_data.head(5)
# Out:
#    Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0  Female         0           No   Yes  Month-to-month      No    Yes   18
# 1  Female         0           No   Yes  Month-to-month      No    Yes   19
# 2    Male         0           No   Yes  Month-to-month     Yes     No   22
# 3  Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4    Male         0           No   Yes  Month-to-month     Yes    Yes   23
#
#     Salary  Base_pay     Bonus  Unit_Price    Volume  openingbalance  \
# 0  5089.00  2035.600  254.4500        3.77  21226600            3.75
# 1  5698.12  2279.248  284.9060        3.74  10462800            3.85
# 2  5896.65  2358.660  294.8325        3.89  18761000            4.23
# 3  6125.12  2450.048  306.2560        4.35  66130600            4.26
# 4  6245.00  2498.000  312.2500        4.34  26868200            4.79
#
#    closingbalance   low  Unit_Sales  Total_Sales  Months            Education
# ...

# %%
##using head function to get last 5rows of data
hr_data.tail(5)
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
#          Salary   Base_pay     Bonus  Unit_Price   Volume  openingbalance  \
# 4995  180696.80  72278.720  9034.840  629.511067  3927000             NaN
# 4996  185685.90  74274.360  9284.295  627.841071  6031900             NaN
# 4997  192636.80  77054.720  9631.840  625.860033  7949400             NaN
# 4998  195970.70  78388.280  9798.535  629.510005  3908400             NaN
# 4999  199970.74  79988.296  9998.537  627.839984  6003300             NaN
#
# ...

# %% [markdown]
# #### **This dataset contains 5000 ROWS and 20 columns**
#
#  **Qualitative data is categorical variables and which are two types one is Nominal and other is ordinal**
# - Gender - talks of the gender - Male or female --Qualitative Variable (Nominal)
# - Business - if the person has a business or no --Qualitative Variable (Nominal)
# - Dependants - number of people dependant on the person --Qualitative Variable (Nominal)
# - Calls - if the person has authority to make calls or no --Qualitative Variable (Nominal)
# - Type - salary settlement type --Qualitative Variable (Nominal)
# - Billing - Subscribed to billing plans or no --Qualitative Variable (Nominal)
# - Education- Educational background of an employee --Qualitative Variable (Ordinal)
# - Rating - If he has been given a rating by a superior or no --Qualitative Variable (Nominal)
#
# **Quantitative data is the numerical variables and it has two types that are discrete and continous**
# - Age - age of the person --Quantitative Variable (Discrete)
# - Salary - CTC of the employee --Quantitative Variable (Continuous)
# - Months - duration of the person employed with the company --Quantitative Variable (Discrete)
# - Unit sales - unit sale made by the person --Quantitative Variable (Continuous)
# - Total sales - total sales made by the person --Quantitative Variable (Continuous)
# - Bonus - amount received by a person as bonus for sales --Quantitative Variable (Continuous)
# - Base pay - Base pay of the employee --Quantitative Variable (Continuous)
# - Unit price - The Unit price of a sale --Quantitative Variable (Continuous)
# - Volume - volume allotted to a person --Quantitative Variable (Continuous)
# - Opening balance - The opening balance of an employee --Quantitative Variable (Continuous)
# - Low - lowest balance allotted to a person. --Quantitative Variable (Continuous)
# - Closing Balance- The closing balance of an employee --Quantitative Variable (Continuous)

# %%
#using nunique function to get the count of unique values
hr_data.nunique()
# Out:
# Gender               2
# Business             2
# Dependancies         2
# Calls                2
# Type                 3
# Billing              2
# Rating               2
# Age                 65
# Salary            5000
# Base_pay          4883
# Bonus             5000
# Unit_Price        3836
# Volume            4831
# openingbalance    2986
# closingbalance    4011
# low               4014
# Unit_Sales        1434
# Total_Sales       4705
# Months              73
# Education            4
# dtype: int64

# %%
hr_data.describe()
# Out:
#           Business          Age         Salary      Base_pay        Bonus  \
# count  5000.000000  5000.000000    5000.000000   4977.000000  5000.000000
# mean      0.160000    51.865000   99821.928553  40046.187707  4991.096428
# std       0.366643     8.560691   25376.961744  10135.686075  1268.848087
# min       0.000000    18.000000    5089.000000   2035.600000   254.450000
# 25%       0.000000    47.000000   83890.338980  33720.552420  4194.516950
# 50%       0.000000    52.000000  100579.378500  40282.016040  5028.968925
# 75%       0.000000    57.000000  116912.092475  46792.232410  5845.604624
# max       1.000000    88.000000  199970.740000  79988.296000  9998.537000
#
#         Unit_Price        Volume  openingbalance  closingbalance          low  \
# count  5000.000000  5.000000e+03     3524.000000     5000.000000  5000.000000
# mean     51.258522  6.761260e+06       43.922020       43.577828    43.034129
# ...

# %%
hr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        4977 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  3524 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %%
#sum of missing values are exist in dataset
hr_data.isnull().sum()
# Out:
# Gender               0
# Business             0
# Dependancies         0
# Calls                0
# Type                 0
# Billing              0
# Rating               0
# Age                  0
# Salary               0
# Base_pay            23
# Bonus                0
# Unit_Price           0
# Volume               0
# openingbalance    1476
# closingbalance       0
# low                  0
# Unit_Sales           0
# Total_Sales         16
# Months               0
# Education            0
# dtype: int64

# %% [markdown]
# **There are missing values present on Base_pay,openingbalance,Total_sales**

# %%
#percentage of missing values
hr_data.isnull().mean()*100
# Out:
# Gender             0.00
# Business           0.00
# Dependancies       0.00
# Calls              0.00
# Type               0.00
# Billing            0.00
# Rating             0.00
# Age                0.00
# Salary             0.00
# Base_pay           0.46
# Bonus              0.00
# Unit_Price         0.00
# Volume             0.00
# openingbalance    29.52
# closingbalance     0.00
# low                0.00
# Unit_Sales         0.00
# Total_Sales        0.32
# Months             0.00
# Education          0.00
# dtype: float64

# %% [markdown]
# **Percentage of missing values,**
# **openingbalance is 29.52**  |
# **Base_pay       is 0.46**  |
# **Total_Sales    is 0.32** |

# %%
#importing missingno library to show missing values
import missingno as msno

# %%
#visualization of missing values in various columns
msno.bar(hr_data)

# %% [markdown]
# **Missing data visualization**

# %% [markdown]
# **Before imputation checking the distribution of variables which are  having missing values**

# %%
sns.set(style="darkgrid")                                        # setting grid to plots
fig,((ax1,ax2,ax3))=plt.subplots(1,3,figsize=(15,4))            # Plotting size of figure
fig.tight_layout()                                            # Plotting layout of each subplot
sns.histplot(hr_data['Base_pay'],kde=True,ax=ax1)
sns.histplot(hr_data['Total_Sales'],kde=True,ax=ax2)
sns.histplot(hr_data['openingbalance'],kde=True,ax=ax3)
plt.title("Distribution Before handling missing values") 
plt.show()

# %% [markdown]
# **base pay having  normaldistribution where totalsales and have not normal distrbution**

# %% [markdown]
# #**Handling Missing values**

# %% [markdown]
# **Imputation**
#
#
#
# **Imputation is technique used for replacing the missing data with some reasonable value(Mean,Median and Mode) to retain most of the data or
# information of the dataset.**
#
#
# **Here Im using KNN Imputer, The idea in kNN methods is to identify 'k' samples in the dataset that are similar or close in the space. Then we use these 'k' samples to estimate the value of the missing data points. Each sample's missing values are imputed using the mean value of the 'k'-neighbors found in the dataset. It can give important information to predict the value of our dependent vairable.**

# %%
#importing knnimputer from sklearn
from sklearn.impute import KNNImputer
x=hr_data[['Base_pay','openingbalance','Total_Sales']]

imputer=KNNImputer(n_neighbors=3)
x=imputer.fit_transform(x)

# %%
#creating dataframe with theese variables
hr_data[['Base_pay','openingbalance','Total_Sales']]= pd.DataFrame(x,columns=['Base_pay','openingbalance','Total_Sales'])

# %%
hr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        5000 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  5000 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %% [markdown]
# **Drop unneccesary features**

# %%
# base pay         - Base pay of the employee, this variable dependent on salary(dependent), so lets drop.
# openingbalance   - missing values of  29.52% so its huge missing values so lets drop.
hr_data=hr_data.drop(['Base_pay','openingbalance'],axis=1)
hr_data.columns
# Out:
# Index(['Gender', 'Business', 'Dependancies', 'Calls', 'Type', 'Billing',
#        'Rating', 'Age', 'Salary', 'Bonus', 'Unit_Price', 'Volume',
#        'closingbalance', 'low', 'Unit_Sales', 'Total_Sales', 'Months',
#        'Education'],
#       dtype='object')

# %% [markdown]
# **Large number of people are not dependant on the person**

# %%
#we have 10 numerical columns and 8 categorical columns
num_cols=['Age', 'Salary', 'Bonus', 'Unit_Price',
       'Volume', 'closingbalance', 'low', 'Unit_Sales',
       'Total_Sales', 'Months']
cat_cols=['Business','Gender', 'Dependancies', 'Calls', 'Type', 'Billing', 'Rating',
       'Education']

# %%
from scipy.stats import skew
for i in num_cols:
  print(i,"skew",skew(hr_data[i]))
  plt.figure(figsize=(10,5))
  sns.histplot(hr_data[i],color="#68228B", kde=True, stat="count", linewidth=1)
  plt.axvline(x=hr_data[i].mean(),color="orange",alpha=1.0,label="Mean")
  plt.axvline(x=hr_data[i].median(),color="c",alpha=1.0,label="Median")
  plt.show()
# Out:
# Age skew -0.25989346454123136
# Salary skew -0.3959227776154577
# Bonus skew -0.3959227777431069
# Unit_Price skew 5.987865994265545
# Volume skew 8.707122057422051
# closingbalance skew 3.225400059391637
# low skew 3.2326965274396677
# Unit_Sales skew -0.22537960434031343
# Total_Sales skew 0.973574569770443
# Months skew 0.2571966118774309

# %% [markdown]
# **From above visuals :**
#      **Age,salary,basepay,bonus are normally distributed**
# **where others like unitprice,volume, closingbalance,low,tsales,totalsales,months are not normally distributed**

# %% [markdown]
# ## **correlation**

# %% [markdown]
# **Correlation is a bivariate analysis that measures the strength of association between two variables and the direction of the relationship.**
# **Spearman rank correlation: Spearman rank correlation is a non-parametric test that is used to measure the degree of association between two variables.****

# %%
hr_data2=hr_data.copy()

# %%
hr_data2.head(3)
# Out:
#    Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0  Female         0           No   Yes  Month-to-month      No    Yes   18
# 1  Female         0           No   Yes  Month-to-month      No    Yes   19
# 2    Male         0           No   Yes  Month-to-month     Yes     No   22
#
#     Salary     Bonus  Unit_Price    Volume  closingbalance   low  Unit_Sales  \
# 0  5089.00  254.4500        3.77  21226600            3.76  3.65       18.25
# 1  5698.12  284.9060        3.74  10462800            3.68  3.65       18.40
# 2  5896.65  294.8325        3.89  18761000            4.29  3.72       18.70
#
#    Total_Sales  Months            Education
# 0        18.80       0  High School or less
# 1        18.85       0  High School or less
# 2        18.90       0  High School or less

# %%
#correlation in numerical variables
hr_data2[num_cols].corr(method='spearman')
# Out:
#                      Age    Salary     Bonus  Unit_Price    Volume  \
# Age             1.000000  0.202282  0.202282    0.128266 -0.039345
# Salary          0.202282  1.000000  1.000000    0.811713 -0.390488
# Bonus           0.202282  1.000000  1.000000    0.811713 -0.390488
# Unit_Price      0.128266  0.811713  0.811713    1.000000 -0.324230
# Volume         -0.039345 -0.390488 -0.390488   -0.324230  1.000000
# closingbalance  0.440989  0.346498  0.346498    0.263699 -0.147108
# low             0.202040  0.999859  0.999859    0.812412 -0.392209
# Unit_Sales      0.202268  0.999997  0.999997    0.811735 -0.390505
# Total_Sales     0.202076  0.999933  0.999933    0.811683 -0.390486
# Months          0.222837  0.603796  0.603796    0.550062 -0.262077
#
#                 closingbalance       low  Unit_Sales  Total_Sales    Months
# Age                   0.440989  0.202040    0.202268     0.202076  0.222837
# Salary                0.346498  0.999859    0.999997     0.999933  0.603796
# ...

# %%
#Visualization of spearman rank correlation using Heatmap
plt.figure(figsize=(20,8))
sns.heatmap(hr_data2[num_cols].corr(method="spearman"),annot=True)

# %% [markdown]
# **From above Correlation analysis, Basepay, bonus, unitprice, low, unitsales, totalsales are correlated with salary**

# %%
corr_var=['Bonus','Unit_Price','low','Unit_Sales','Total_Sales']
sns.set(style="darkgrid")    # setting grid to plots
fig,((ax1,ax2),(ax3,ax4),(ax5,ax6))=plt.subplots(3,2,figsize=(12,12))   # Plotting size of figure
fig.tight_layout()                      # Plotting layout of each subplot
sns.scatterplot(x='Bonus',y='Salary',data=hr_data2,ax=ax1)
sns.scatterplot(x='Unit_Price',y='Salary',data=hr_data2,ax=ax2)
sns.scatterplot(x='low',y='Salary',data=hr_data2,ax=ax3)
sns.scatterplot(x='Unit_Sales',y='Salary',data=hr_data2,ax=ax4)
sns.scatterplot(x='Total_Sales',y='Salary',data=hr_data2,ax=ax5)
plt.show()

# %% [markdown]
# **from above plot, we have basepay,bonus are linear relationship with salary and others are not in linear relationship**

# %% [markdown]
# ## **Relationship between salary with categorical features**

# %%
#categorical variables
cat_cols=['Business','Gender','Dependancies','Calls','Type','Billing','Rating','Education']

# %%
sns.boxplot(x="Gender",y="Salary",data=hr_data2)

# %% [markdown]
# **From above, we have males and females who's Mean value is equal**

# %% [markdown]
# **TTEST**
#
# **A t-test is a type of inferential statistic used to determine if there is a significant difference between the means of two groups.**
#
#    **Assumptions:**
#
#
#
# *   **homogeneity of variance**
# *   **normal distribution of data.**

# %% [markdown]
# **TTEST on Gender**

# %%
#importing pingouin library
import pingouin as pg                #pingouin
from pingouin import ttest          #ttets
from pingouin import kruskal       #kruskal wallis test
from pingouin import mwu          #mann whitneyu-test
from scipy.stats import levene   #levene

# %%
#coducting ttest
male=hr_data2[hr_data2['Gender']=='Male']['Salary']
female=hr_data2[hr_data2['Gender']=='Female']['Salary']

# %% [markdown]
# **pingouin normalty test on each variance:**

# %%
#checking for normality
print(pg.normality(male))
print(pg.normality(female))
# Out:
#                W          pval  normal
# Salary  0.986601  1.081249e-14   False
#                W          pval  normal
# Salary  0.986174  9.088472e-15   False

# %% [markdown]
# **Levene's test (test of equality(homogenity) of variance:**
#
#   It is an inferential statistic used to assess the equality of variances for a variable calculated for two or more groups

# %%
#levene
print(levene(male,female))                 # from p value this is not significant.that means equal variance not assumed
# Out:
# LeveneResult(statistic=0.7626280645351884, pvalue=0.38254928043414826)

# %%
#ttest
ttest(male,female,paired=True)
# Out:
#               T          dof alternative     p-val              CI95%  \
# T-test  1.54332  4995.472454   two-sided  0.122817  [-299.37, 2514.7]
#
#          cohen-d   BF10     power
# T-test  0.043654  0.104  0.338591

# %% [markdown]
# from above normality, levenes test, we obeserve that groups are not normal and unequal variance assumed. so ttest is not good for this significant test

# %% [markdown]
# **Mann whitney test**
#
# The independent variable should be two independent, categorical groups. Observations should be independent.
# In other words, there should be no relationship between the two groups or within each group. Observations are not normally distributed.

# %%
#mann whitney test
print(mwu(male,female))
# Out:
#          U-val alternative     p-val       RBC      CLES
# MWU  3189645.0   two-sided  0.202521 -0.020814  0.510407

# %% [markdown]
# **p-value is higher than 0.05. then there is NO-SIGNIFICANCE. so that there is -no- impact of gender on salary**

# %% [markdown]
# ### **Business**

# %%
#boxplot 
sns.boxplot(x="Business",y="Salary",data=hr_data2)

# %% [markdown]
# **From above plot we have employee has bussiness and no bussiness who's mean value is equal**

# %% [markdown]
# **TTEST On Business**

# %%
#applying ttest
bussy=hr_data2[hr_data2['Business']==1]['Salary']
bussn=hr_data2[hr_data2['Business']==0]['Salary']

ttest(bussy ,bussn ,paired=True)
# Out:
#               T          dof alternative     p-val                CI95%  \
# T-test -0.59667  1137.710826   two-sided  0.550846  [-2473.44, 1319.87]
#
#          cohen-d   BF10     power
# T-test  0.022727  0.052  0.090601

# %%
#checking for normality
print(pg.normality(bussy))
print(pg.normality(bussn))

#levene
print(levene(bussy,bussn))
# Out:
#                W      pval  normal
# Salary  0.993729  0.002016   False
#                W          pval  normal
# Salary  0.985058  1.110142e-20   False
# LeveneResult(statistic=0.16695286536825213, pvalue=0.6828517190773632)

# %%
#mann whitney test
mwu(bussy,bussn)
# Out:
#          U-val alternative     p-val       RBC      CLES
# MWU  1631311.0   two-sided  0.193216  0.028982  0.485509

# %% [markdown]
# **p-value is higher than 0.05. then there is NO-SIGNIFICANCE. so that there is no impact of bussiness on salary**

# %% [markdown]
# ### **Dependancies**

# %%
sns.set(style="darkgrid")        # setting grid to plots
sns.boxplot(x="Dependancies",y="Salary",data=hr_data2)  #  boxplot for Dependancies

# %% [markdown]
# **From above plot, Dependencies yes and no has equal mean value**

# %% [markdown]
# **TTEST On Dependancies**

# %%
#applying ttest
depy=hr_data2[hr_data2['Dependancies']=='Yes']['Salary']
depn=hr_data2[hr_data2['Dependancies']=='No']['Salary']
ttest(depy ,depn ,paired=True)
# Out:
#               T          dof alternative     p-val               CI95%  \
# T-test  0.44767  2822.480976   two-sided  0.654426  [-1179.92, 1878.1]
#
#          cohen-d   BF10     power
# T-test  0.013755  0.039  0.072828

# %%
#checking for normality
print(pg.normality(depy))
print(pg.normality(depn))

#levene
print(levene(depy,depn))
# Out:
#               W          pval  normal
# Salary  0.98869  2.711714e-09   False
#                W          pval  normal
# Salary  0.986277  5.236985e-18   False
# LeveneResult(statistic=0.8049422439713707, pvalue=0.3696630289373688)

# %%
#mann whitney test
mwu(depy,depn)
# Out:
#          U-val alternative     p-val       RBC      CLES
# MWU  2617195.0   two-sided  0.723326 -0.006338  0.503169

# %% [markdown]
# **p-value is higher than 0.05. then there is NO-SIGNIFICANCE. so that there is no impact of Dependancies on salary**

# %% [markdown]
# ### **Calls**

# %%
sns.boxplot(x="Calls",y="Salary",data=hr_data2)

# %% [markdown]
# **From above plot, Autority to make calls has high in mean compare with No autority to make calls mean value**

# %% [markdown]
# **TTEST On Calls**

# %%
#applying ttest
caly=hr_data2[hr_data2['Calls']=='Yes']['Salary']
caln=hr_data2[hr_data2['Calls']=='No']['Salary']
ttest(caly ,caln ,paired=True)
# Out:
#                T         dof alternative     p-val             CI95%  \
# T-test  2.189608  562.278985   two-sided  0.028963  [274.45, 5057.4]
#
#          cohen-d  BF10     power
# T-test  0.105091  0.59  0.575165

# %%
#checking for normality
print(pg.normality(caly))
print(pg.normality(caln))

#levene
print(levene(caly,caln))
# Out:
#                W          pval  normal
# Salary  0.987678  1.754513e-19   False
#                W      pval  normal
# Salary  0.977362  0.000001   False
# LeveneResult(statistic=0.8137294465026199, pvalue=0.36706339962472134)

# %%
#mann whitney test
mwu(caly,caln)
# Out:
#          U-val alternative     p-val       RBC      CLES
# MWU  1110774.0   two-sided  0.028863 -0.061682  0.530841

# %% [markdown]
# **p-value is SIGNIFICANCE ,so that calls having impact on salary**

# %% [markdown]
# ### **Billing**

# %%
sns.boxplot(x="Billing",y="Salary",data=hr_data2)

# %% [markdown]
# **From above plot, Billing yes and Billing no has equal mean value**

# %% [markdown]
# **TTEST On Billing**

# %%
#applying ttest
billy=hr_data2[hr_data2['Billing']=='Yes']['Salary']
billn=hr_data2[hr_data2['Billing']=='No']['Salary']
ttest(billy ,billn ,paired=True)
# Out:
#                T          dof alternative     p-val               CI95%  \
# T-test  0.607969  4486.111513   two-sided  0.543239  [-981.38, 1863.65]
#
#          cohen-d   BF10     power
# T-test  0.017382  0.039  0.092748

# %%
#checking for normality
print(pg.normality(billy))
print(pg.normality(billn))

#levene
print(levene(billy,billn))
# Out:
#                W          pval  normal
# Salary  0.987039  8.477778e-16   False
#                W          pval  normal
# Salary  0.986385  4.944108e-13   False
# LeveneResult(statistic=3.0449640651694994, pvalue=0.08104936723098867)

# %%
#mann whitney test
mwu(billy,billn)
# Out:
#          U-val alternative     p-val       RBC      CLES
# MWU  3051588.0   two-sided  0.542579 -0.010114  0.505057

# %% [markdown]
# **p-value is higher than 0.05. then there is NO-SIGNIFICANCE . so that there is no impact of billing on salary**

# %% [markdown]
# ### **Rating**

# %%
sns.boxplot(x="Rating",y="Salary",data=hr_data2)

# %% [markdown]
# **From above plot, Rating yes and Rating no has equal mean value**

# %% [markdown]
# **TTEST On Rating**

# %%
#applying ttest
ratey=hr_data2[hr_data2['Rating']=='Yes']['Salary']
raten=hr_data2[hr_data2['Rating']=='No']['Salary']
ttest(ratey ,raten ,paired=True)
# Out:
#              T          dof alternative     p-val                CI95%  \
# T-test  0.5702  2295.799151   two-sided  0.568598  [-1139.99, 2074.74]
#
#          cohen-d   BF10     power
# T-test  0.018416  0.043  0.088467

# %%
#checking for normality
print(pg.normality(ratey))
print(pg.normality(raten))

#levene
print(levene(ratey,raten))
# Out:
#                W          pval  normal
# Salary  0.982725  1.918370e-11   False
#                W          pval  normal
# Salary  0.988365  7.613624e-17   False
# LeveneResult(statistic=0.11523918394864803, pvalue=0.7342707296287778)

# %%
#mann whitney test
mwu(ratey,raten)
# Out:
#          U-val alternative    p-val       RBC      CLES
# MWU  2457307.0   two-sided  0.49246 -0.012722  0.506361

# %% [markdown]
# **p-value is higher than 0.05. then there is NO-SIGNIFICANCE. so that there is no impact of Rating on salary**

# %% [markdown]
# ### **Type**

# %%
sns.boxplot(x="Type",y="Salary",data=hr_data2)

# %% [markdown]
# **From above plot, Month to Month, Two year type and one year type who's mean value almost same**

# %% [markdown]
# **ANOVA test on Type**
#
# **Analysis of variance, or ANOVA, is a statistical method that separates observed variance data into different components to use for additional tests. A one-way ANOVA is used for three or more groups of data, to gain information about the relationship between the dependent and independent variables.**

# %%
#Here using ANOVA TEST to see impact
grp=hr_data2['Type'].tolist()
val=hr_data2['Salary'].tolist()
type_d=pd.DataFrame(list(zip(grp,val)), columns=['group','value'])
type_d.head(2)
# Out:
#             group    value
# 0  Month-to-month  5089.00
# 1  Month-to-month  5698.12

# %%
#checking for normality
t1=hr_data2[hr_data2['Type']=='Month-to-month']['Salary']
t2=hr_data2[hr_data2['Type']=='Two year']['Salary']
t3=hr_data2[hr_data2['Type']=='One year']['Salary']
print(pg.normality(t1))
print(pg.normality(t2))
print(pg.normality(t3))

#levene
print(levene(t1,t2,t3))
# Out:
#                W          pval  normal
# Salary  0.987068  3.259373e-15   False
#                W          pval  normal
# Salary  0.989047  8.691035e-08   False
#                W          pval  normal
# Salary  0.981895  5.306845e-10   False
# LeveneResult(statistic=1.883401694804317, pvalue=0.1521798574382571)

# %%
aov=pg.anova(data=type_d,dv='value',between='group',detailed=True)
aov
# Out:
#    Source            SS    DF            MS         F    p-unc       np2
# 0   group  2.420365e+09     2  1.210183e+09  1.879856  0.15272  0.000752
# 1  Within  3.216887e+12  4997  6.437636e+08       NaN      NaN       NaN

# %% [markdown]
# #### **Kruskal-wallis test (H-test)**
# **kruskal-wallis test(H-test): beacase normality and equal variance assuptions are violated**

# %%
#kruskal-wallis test(H-test) beacase normality and equal variance assuptions are violated 
pg.kruskal(data=type_d,dv='value',between='group')
# Out:
#         Source  ddof1         H     p-unc
# Kruskal  group      2  4.033266  0.133103

# %% [markdown]
# **p-value is higher than 0.05. then there is NO-SIGNIFICANCE. so that there is no impact of type on salary**

# %% [markdown]
# ### **Education**

# %%
sns.boxplot(x="Education",y="Salary",data=hr_data2)

# %% [markdown]
# **From above plot,employee has PG is more, second most place is taken by graduation and High school, intermediate are approximatly equal,taken last place**

# %% [markdown]
# **ANOVA test on Education**

# %%
#creating group,values for ANOVA test
grp=hr_data2['Education'].tolist()
val=hr_data2['Salary'].tolist()
edu_d=pd.DataFrame(list(zip(grp,val)), columns=['group','value'])
edu_d.head(2)
# Out:
#                  group    value
# 0  High School or less  5089.00
# 1  High School or less  5698.12

# %%
#checking for normality
t1=hr_data2[hr_data2['Education']=='High School or less']['Salary']
t2=hr_data2[hr_data2['Education']=='Intermediate']['Salary']
t3=hr_data2[hr_data2['Education']=='Graduation']['Salary']
t4=hr_data2[hr_data2['Education']=='PG']['Salary']
print(pg.normality(t1))
print(pg.normality(t2))
print(pg.normality(t3))
print(pg.normality(t4))

#levene
print(levene(t1,t2,t3,t4))
# Out:
#                W      pval  normal
# Salary  0.817727  0.008339   False
#                W      pval  normal
# Salary  0.755502  0.000025   False
#                W          pval  normal
# Salary  0.941733  3.053259e-27   False
#                W          pval  normal
# Salary  0.992907  6.522455e-11   False
# LeveneResult(statistic=77.46245962181939, pvalue=5.665861028944939e-49)

# %%
#anova
aov=pg.anova(data=edu_d,dv='value',between='group',detailed=True)
aov
# Out:
#    Source            SS    DF            MS           F          p-unc  \
# 0   group  6.023912e+11     3  2.007971e+11  383.345222  4.325943e-224
# 1  Within  2.616916e+12  4996  5.238022e+08         NaN            NaN
#
#         np2
# 0  0.187118
# 1       NaN

# %%
#kruskal-wallis test(u-test) beacase normality and equal variance assuptions are violated 
kl=pg.kruskal(data=edu_d,dv='value',between='group')
kl
# Out:
#         Source  ddof1           H          p-unc
# Kruskal  group      3  539.051625  1.640535e-116

# %% [markdown]
#  **p-value is negetive. then there is SINGIFICANCE difference. so that there is impact of Education on salary**

# %% [markdown]
# **posthoc analysis**

# %%
#posthoc analysis on education
#to know what senarios are significance 
pairwise_test=pg.pairwise_tukey(dv='value',between='group',data=edu_d)
pairwise_test
# Out:
#                      A                    B       mean(A)        mean(B)  \
# 0           Graduation  High School or less  91731.465271    8021.192905
# 1           Graduation         Intermediate  91731.465271    8797.040201
# 2           Graduation                   PG  91731.465271  106455.698134
# 3  High School or less         Intermediate   8021.192905    8797.040201
# 4  High School or less                   PG   8021.192905  106455.698134
# 5         Intermediate                   PG   8797.040201  106455.698134
#
#            diff           se          T  p-tukey    hedges
# 0  83710.272366  6138.321331  13.637323  0.00000  3.656213
# 1  82934.425070  4434.481673  18.702169  0.00000  3.622336
# 2 -14724.232863   663.609910 -22.188085  0.00000 -0.643255
# 3   -775.847296  7537.540935  -0.102931  0.99961 -0.033243
# 4 -98434.505229  6131.090748 -16.054974  0.00000 -4.299865
# 5 -97658.657933  4424.467504 -22.072409  0.00000 -4.265978

# %% [markdown]
# *    **Inter ,graduation,pg are having significant difference**
# *    **there are no significant differece on  high school or less and inter**

# %% [markdown]
# ### **based on correlation analysis we have Bonus, base_pay, unit_price,low,unit_sales,total_sales,education,calls are using for our model**

# %%
#droping unwanted columns from our dataset
hr_data2.drop(columns=['Gender','Business','Dependancies','Type','Billing','Rating','Age','Volume','closingbalance','Months'],inplace=True)

# %%
#required columns for our modeling
hr_data2.columns
# Out:
# Index(['Calls', 'Salary', 'Bonus', 'Unit_Price', 'low', 'Unit_Sales',
#        'Total_Sales', 'Education'],
#       dtype='object')

# %%
hr_data2.head(2)
# Out:
#   Calls   Salary    Bonus  Unit_Price   low  Unit_Sales  Total_Sales  \
# 0   Yes  5089.00  254.450        3.77  3.65       18.25        18.80
# 1   Yes  5698.12  284.906        3.74  3.65       18.40        18.85
#
#              Education
# 0  High School or less
# 1  High School or less

# %% [markdown]
# ## **Feature Engineering**

# %% [markdown]
# ***Here using get_dummies method to convert data to binary form***

# %%
hr_data2.Calls=pd.get_dummies(hr_data2.Calls,drop_first=True)
hr_data2.Calls.head(8)
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# 5    1
# 6    0
# 7    1
# Name: Calls, dtype: uint8

# %% [markdown]
# **here using Label Encoder to encoding education column**

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
#using this method to tranform corresponding values to their respective columns
hr_data2.Education=le.fit_transform(hr_data2.Education)
hr_data2.Calls=le.fit_transform(hr_data2.Calls)

# %% [markdown]
# ## **Also checking required features with mutual informantion tequnique**

# %% [markdown]
# Mutual Information
# Estimate mutual information for both categorical and continuous target variables.
#
# Mutual information (MI) between two random variables is a non-negative value, which measures the dependency between the variables. It is equal to zero if and only if two random variables are independent, and higher values mean higher dependency.
#
# The function relies on nonparametric methods based on entropy estimation from k-nearest neighbors distances
#
# Mutual information is calculated between two variables and measures the reduction in uncertainty for one variable given a known value of the other variable.
#
# Inshort
#
# A quantity called mutual information measures the amount of information one can obtain from one random variable given another.
#
# The mutual information between two random variables X and Y can be stated formally as follows:
#
# I(X ; Y) = H(X) – H(X | Y) Where I(X ; Y) is the mutual information for X and Y, H(X) is the entropy for X and H(X | Y) is the conditional entropy for X given Y. The result has the units of bits.

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(hr_data2.drop(labels=['Salary'],axis=1),hr_data2['Salary'],test_size=0.2,random_state=0)

# %%
from sklearn.feature_selection import mutual_info_regression
# determine the mutual information
mutual_info = mutual_info_regression(x_train, y_train)
mutual_info
# Out:
# array([0.        , 7.03780697, 3.52381629, 4.29870684, 5.81962775,
#        5.98615403, 0.6840716 ])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = x_train.columns
mutual_info.sort_values(ascending=False)
# Out:
# Bonus          7.037807
# Total_Sales    5.986154
# Unit_Sales     5.819628
# low            4.298707
# Unit_Price     3.523816
# Education      0.684072
# Calls          0.000000
# dtype: float64

# %%
mutual_info.sort_values(ascending=False).plot.bar(figsize=(15,5))

# %% [markdown]
# **Low feature not important for model building**

# %% [markdown]
# ## **Model building**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(hr_data2.drop(labels=['Salary'],axis=1),hr_data2['Salary'],test_size=0.2,random_state=0)

x_train.drop(labels=['Calls'],axis=1,inplace=True)
x_test.drop(labels=['Calls'],axis=1,inplace=True)


x=hr_data2.drop(labels=['Salary'],axis=1)
y=hr_data2['Salary']

# %%
x_train.head(5)
# Out:
#             Bonus  Unit_Price        low  Unit_Sales  Total_Sales  Education
# 2913  5278.778365   38.150002  37.549999       77.35      1871.85          3
# 3275  5521.581875   44.130001  43.509998       82.65      2596.15          3
# 775   3801.525103   39.200000  17.088888       20.70       171.15          0
# 217   2826.632620   10.950000  10.790000       19.60        45.30          0
# 1245  4191.662231   44.110001  21.720000       35.40       383.55          3

# %% [markdown]
# ## **Desicion Tree**
#
# - Decision tree can be used for both classification and regression
# - Here as no feature scaling is required
# - It is robust to the outliers
# - Clear visualization and easy to understand

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
dtr=DecisionTreeRegressor(max_depth=5)
#for fitting
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
#predicting
y_predict=dtr.predict(x_test)

# %%
#apply r2 score to y_test ,y_predict to predict accuracy percentage
y_pred = dtr.predict(x_train)
print(' r2 score for Training :',r2_score(y_train,y_pred)) #print of r2 score for train
print('Mean Squared Error for Training: ',mean_squared_error(y_train,y_pred))  #Print MSE value for train
print('Root Mean Squared Error for Training: ',np.sqrt(mean_squared_error(y_train,y_pred)))  #Print RMSE value for train
print('---------------------------------------------')

score=metrics.r2_score(y_test,y_predict)
print("r2-score=",score)
print("Mean Squared Error:",mean_squared_error(y_test,y_predict))
print("Root mean squared error:",np.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
#  r2 score for Training : 0.9973729915971473
# Mean Squared Error for Training:  1690851.8129480495
# Root Mean Squared Error for Training:  1300.327579092303
# ---------------------------------------------
# r2-score= 0.997022755825611
# Mean Squared Error: 1919548.8913089118
# Root mean squared error: 1385.477856664953

# %%
#Importing tree from sklearn library,to display data visalization of DecisiontreeRegressor
from sklearn import tree
plt.figure(figsize=(15,8))
tree.plot_tree(dtr,feature_names=x_train.columns,max_depth=5,filled=True)
plt.show()

# %% [markdown]
# **CROSS-VALIDATION, PERFORMANCE-CHECK**
#
# Here we are using Repeated Random Test_Train splits cross validation:
# This technique is a hybrid of traditional train_test splitting and the k-fold cross validation method. In this technique,we create random splits of data in the training-set manner and then repeat the process of splitting and evaluating the algorithm multiple times,just like the cross-validation method.

# %%
#Importing shfflesplit using sklearn library
from sklearn.model_selection import ShuffleSplit
model=DecisionTreeRegressor(max_depth=5)
shs=ShuffleSplit(n_splits=10,test_size=0.20) 
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=shs)
print(results)
print(np.mean(results))
# Out:
# [0.99592629 0.99672435 0.99527065 0.99653943 0.99646029 0.99662351
#  0.99374317 0.99707527 0.99738423 0.99693978]
# 0.9962686986238587

# %% [markdown]
# **RMSC is 1385**
#
# **average accuracy score for DecisionTreeRegressor is 99%**

# %% [markdown]
# ## **Random Forest**
#
# - It works well with both categorical and continous values
# - Robust to outliers
# - feature scaling is not required
# - It reduces overfitting in decision trees and help to improve the accuracy
# - It automates missing values present in the data

# %%
from pandas.core.common import random_state
from sklearn.ensemble import RandomForestRegressor

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rfr_pred=rfr.predict(x_test)

# %%
#predicting the results using x_train
y_pred = rfr.predict(x_train)
print(' r2 score for Training :',r2_score(y_train,y_pred)) #print of r2 score for train
print('Mean Squared Error for Training: ',mean_squared_error(y_train,y_pred))  #Print MSE value for train
print('Root Mean Squared Error for Training: ',np.sqrt(mean_squared_error(y_train,y_pred)))  #Print RMSE value for train
print('---------------------------------------------')
rsquere= metrics.r2_score(y_test,rfr_pred)
print('MSE:',metrics.mean_squared_error(y_test,rfr_pred))
print("Root mean squared error:",np.sqrt(mean_squared_error(y_test,rfr_pred)))
print('r2-score:',format(rsquere))
# Out:
#  r2 score for Training : 0.9999838687408135
# Mean Squared Error for Training:  10382.748989699177
# Root Mean Squared Error for Training:  101.89577513174517
# ---------------------------------------------
# MSE: 11584.762533754412
# Root mean squared error: 107.6325347362702
# r2-score: 0.9999820318894083

# %%
# Cross validation for our model
from sklearn.model_selection import ShuffleSplit
model=RandomForestRegressor(random_state=5)
ssplit=ShuffleSplit(n_splits=10,test_size=0.20)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print(np.mean(results))
# Out:
# [0.99998505 0.99926195 0.99961636 0.99997131 0.99993586 0.99986343
#  0.99994432 0.99992722 0.9999462  0.99998468]
# 0.9998436377542536

# %% [markdown]
# **Training :**
#
# --- **r2 score: 0.99**
#
# ---- **RMSE: 101**
#
# **Testing:**
#
# ---- **r2-score: 0.99**
#
# ---- **RMSE: 107**

# %% [markdown]
# **-------------------------------------------------------------&&------------------------------------------------------------**

# %% [markdown]
# ## **Now try Linear regression**

# %% [markdown]
# **Assumptions:**
#    - Normal distribution
#    - Handle the outliers
#    - feature scaling is required
#    - No or little multicolinearty

# %% [markdown]
# ### **lets prepare data for linear regression**
#
#
#  - Guassian trasformation
#
#  - Handling outliers
#
#  - Feature Scaling
#
#  - Handle multicollinearity
#
#  - Applying Linear Regression
#
#
#  **on appying log trasformation on not normally distributed variables**

# %%
hr_data3=hr_data2.copy()       # for copy datasave side

# %%
hr_data3.isna().sum()          # checking missing values
# Out:
# Calls          0
# Salary         0
# Bonus          0
# Unit_Price     0
# low            0
# Unit_Sales     0
# Total_Sales    0
# Education      0
# dtype: int64

# %%
#required columns
hr_data3.columns
# Out:
# Index(['Calls', 'Salary', 'Bonus', 'Unit_Price', 'low', 'Unit_Sales',
#        'Total_Sales', 'Education'],
#       dtype='object')

# %% [markdown]
# ### ***1.Guassian Transformation***
# Some machine learning algorithms like linear and logistic assume that the features are normally distributed -Accuracy -Performance
#
# - logarithmic transformation
# - reciprocal transformation
# - square root transformation
# - exponential transformation (more general, you can use any exponent)
# - boxcox transformation

# %% [markdown]
# **BoxCOx Transformation**
# The Box-Cox transformation is defined as:
#
# T(Y)=(Y exp(λ)−1)/λ
#
# where Y is the response variable and λ is the transformation parameter. λ varies from -5 to 5. In the transformation, all values of λ are considered and the optimal value for a given variable is selected.

# %%
import scipy.stats as stats

# %%
#applying lock trasformation on unitprice,volume,openingbalance, closingbalance,low,totalsales,months and see ther distibution
import scipy.stats as stats
#hr_data3['Unit_Price']=np.log(hr_data3['Unit_Price'])                      #-0.171
hr_data3['Unit_Price'],parameters=stats.boxcox(hr_data3['Unit_Price'])    # skew: 0.02071
print('unitprice skew:',skew(hr_data3['Unit_Price']))
sns.histplot(hr_data3['Unit_Price'],kde=True)
plt.axvline(x=hr_data3['Unit_Price'].mean(),color="red",alpha=1.0, label="Mean")
plt.axvline(x=hr_data3['Unit_Price'].median(),color="blue",alpha=1.0, label="Median")
plt.show()
# Out:
# unitprice skew: 0.020714784833781735

# %%
#applying lock trasformation on low
#hr_data3['low']=np.log(hr_data3['low'])                            #skew: 1.1373
hr_data3['low'],parameters=stats.boxcox(hr_data3['low'])          #skew: -0.0044
print('low skew:',skew(hr_data3['low']))
sns.histplot(hr_data3['low'],kde=True)
plt.axvline(x=hr_data3['low'].mean(),color="red",alpha=1.0, label="Mean")
plt.axvline(x=hr_data3['low'].median(),color="blue",alpha=1.0, label="Median")
plt.show()
# Out:
# low skew: -0.004463043321670876

# %%
#applying lock trasformation on Total_Sales
#hr_data3['Total_Sales']=(hr_data3['Total_Sales']**(1/1.2))
hr_data3['Total_Sales'],parameters=stats.boxcox(hr_data3['Total_Sales'])
print('Total_Sales skew:',skew(hr_data3['Total_Sales']))
sns.histplot(hr_data3['Total_Sales'],kde=True)
plt.axvline(x=hr_data3['Total_Sales'].mean(),color="red",alpha=1.0, label="Mean")
plt.axvline(x=hr_data3['Total_Sales'].median(),color="blue",alpha=1.0, label="Median")
plt.show()
# Out:
# Total_Sales skew: -0.14316589422473652

# %%
sns.set(style="darkgrid")                                       # setting grid to plots
fig,((ax1,ax2,ax3))=plt.subplots(1,3,figsize=(15,4))            # Plotting size of figure
fig.tight_layout()                                              # Plotting layout of each subplot
sns.histplot(hr_data['Unit_Price'],kde=True,ax=ax1)
sns.histplot(hr_data['low'],kde=True,ax=ax2)
sns.histplot(hr_data['Total_Sales'],kde=True,ax=ax3)
plt.show()

# %%
sns.set(style="darkgrid")                                       # setting grid to plots
fig,((ax1,ax2,ax3))=plt.subplots(1,3,figsize=(15,4))            # Plotting size of figure
fig.tight_layout()                                              # Plotting layout of each subplot
sns.histplot(hr_data3['Unit_Price'],kde=True,ax=ax1)
sns.histplot(hr_data3['low'],kde=True,ax=ax2)
sns.histplot(hr_data3['Total_Sales'],kde=True,ax=ax3)
plt.show()

# %% [markdown]
# **After applying lock trasformation we have unit_price, volume, closingbalance, low are normally distributed.And others like total_sales, months, are not in normality**

# %% [markdown]
# ## **2.Handling Outliers**

# %% [markdown]
# Identify the ouliers using IQR is better method

# %%
#handling outliers in salary column
#checking outliers in this column using box plot
sns.boxplot(hr_data3.Salary)

# %%
#using IQR method to handle the outliers
q1_Salary=hr_data3.Salary.quantile(0.25) # q1_salary=83890.33898
q3_Salary=hr_data3.Salary.quantile(0.75) # q3_salary=116912.092475
IQR_Salary=q3_Salary-q1_Salary          #IQR_salary=33021.753495

# %%
upperwisker_Salary=(q3_Salary+(1.5*IQR_Salary)).astype(int) #upperwisker_age=166444
lowerwisker_Salary=(q1_Salary-(1.5*IQR_Salary)).astype(int) #lowerwisker_age=34357

#percentage
Salary_outs_lwr=len(hr_data3[hr_data3.Salary<lowerwisker_Salary]) #66
Salary_prct_lwr=round((Salary_outs_lwr/hr_data3.shape[0])*100,2) #1.32%

#replece all salary outliers with lowerwisker 
hr_data3['Salary']=np.where(hr_data3['Salary']<lowerwisker_Salary,lowerwisker_Salary,hr_data3['Salary'])

#percentage
Salary_outs_upr=len(hr_data3[hr_data3.Salary>upperwisker_Salary]['Salary']) #11
Salary_prct_upr=round((Salary_outs_upr/hr_data3.shape[0])*100,2) 

#replece all salary outliers with upperwisker 
hr_data3['Salary']=np.where(hr_data3['Salary']>upperwisker_Salary,upperwisker_Salary,hr_data3['Salary'])

# %%
#after handling outliers our salary column
sns.boxplot(hr_data3.Salary)

# %% [markdown]
# **After handle outliers on Salary,there is no outliers**

# %%
#checking outliers in this BONUS column using box plot
sns.boxplot(hr_data3.Bonus)

# %% [markdown]
# **Handling outliers on**

# %%
#using IQR method to handle the outliers
q1_Bonus=hr_data3.Bonus.quantile(0.25) 
q3_Bonus=hr_data3.Bonus.quantile(0.75) 
IQR_Bonus=q3_Bonus-q1_Bonus 

upperwisker_Bonus=(q3_Bonus+(1.5*IQR_Bonus)).astype(int) 
lowerwisker_Bonus=(q1_Bonus-(1.5*IQR_Bonus)).astype(int) 
#percentage
Bonus_outs_lwr=len(hr_data3[hr_data3.Bonus<lowerwisker_Bonus]) #66
Bonus_prct_lwr=round((Bonus_outs_lwr/hr_data3.shape[0])*100,2) #1.32%
#replece all salary outliers with lowerwisker 
hr_data3['Bonus']=np.where(hr_data3['Bonus']<lowerwisker_Bonus,lowerwisker_Bonus,hr_data3['Bonus'])
#percentage
Bonus_outs_upr=len(hr_data3[hr_data3.Bonus>upperwisker_Bonus]['Bonus']) #11
Bonus_prct_upr=round((Bonus_outs_upr/hr_data3.shape[0])*100,2) 
#replece all salary outliers with upperwisker 
hr_data3['Bonus']=np.where(hr_data3['Bonus']>upperwisker_Bonus,upperwisker_Bonus,hr_data3['Bonus'])

# %%
#after handling outliers our salary column
sns.boxplot(hr_data3.Bonus)

# %% [markdown]
# **After handle outliers on bonus,there is no outliers**

# %% [markdown]
# ### **3.Multicollinearity**
#
# Multicollinearity occurs when two or more independent variables are highly correlated with one another in a regression model.
#
#      now we check, if there is correlation between independent variables,then we drop those things from train and test data
#
#
#  here hr_data3 having no missing values and outliers also

# %%
mc=hr_data3.copy()            # copy for safty

# %%
mc.columns                   # to check columns
# Out:
# Index(['Calls', 'Salary', 'Bonus', 'Unit_Price', 'low', 'Unit_Sales',
#        'Total_Sales', 'Education'],
#       dtype='object')

# %%
x=mc.drop(labels=['Salary'],axis=1)                    # x ,y for train_test_split and cross validation
y=mc['Salary']  
from sklearn.model_selection import train_test_split   # for train_test_split 
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=0)
x_train.corr()                                          # to checking correlation between indipendent variables
# Out:
#                 Calls     Bonus  Unit_Price       low  Unit_Sales  \
# Calls        1.000000  0.038457    0.023491  0.038358    0.034694
# Bonus        0.038457  1.000000    0.794387  0.996741    0.957648
# Unit_Price   0.023491  0.794387    1.000000  0.807825    0.745571
# low          0.038358  0.996741    0.807825  1.000000    0.946499
# Unit_Sales   0.034694  0.957648    0.745571  0.946499    1.000000
# Total_Sales  0.037763  0.982747    0.766590  0.972645    0.987961
# Education    0.040271  0.298360    0.259722  0.306043    0.274214
#
#              Total_Sales  Education
# Calls           0.037763   0.040271
# Bonus           0.982747   0.298360
# Unit_Price      0.766590   0.259722
# low             0.972645   0.306043
# Unit_Sales      0.987961   0.274214
# Total_Sales     1.000000   0.290097
# Education       0.290097   1.000000

# %%
#Using Pearson Correlation
plt.figure(figsize=(12,10))
sns.heatmap(x_train.corr(),annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
                                                         # This function will remove multicolinear variables
def correlation(dataset, threshold):
    col_corr = set()                                     # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:  # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]         # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
# Above 80% Correlated Variables Are Saperated
corr_features = correlation(x_train, 0.8)  
# Printing Correlated Cols Leghth
print('correlated cols leghth:',len(set(corr_features))) 
# Printing Highly Correlated Cols
print('highly correlated cols:',corr_features)
# Out:
# correlated cols leghth: 3
# highly correlated cols: {'Unit_Sales', 'low', 'Total_Sales'}

# %%
# Drop Correlated Independent Variables From x_train
x_train.drop(labels=['Total_Sales', 'Unit_Sales', 'low'],axis=1,inplace=True)

# %%
# Drop Correlated Independent Variables From x_test
x_test.drop(labels=['Total_Sales', 'Unit_Sales', 'low'],axis=1,inplace=True)

# %%
x_train.columns    # Low or Min Correlated Columns
# Out:
# Index(['Calls', 'Bonus', 'Unit_Price', 'Education'], dtype='object')

# %%
plt.figure(figsize=(12,10))
sns.heatmap(x_train.corr(),annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
# x-Independent Variables(Choosen According To Multicorretion )
x=pd.DataFrame(data=mc,columns=['Calls', 'Unit_Price', 'Education'])
# Y-Dependent Variable(Choosen by Problem Statement)
y=mc['Salary']
# Required Variables

x_train=x_train.drop('Bonus',axis=1)
x_test=x_test.drop('Bonus',axis=1)

# %% [markdown]
# ### **4.Feature scaling**

# %%
from sklearn.preprocessing import StandardScaler   #standarisation:
scaler=StandardScaler()
# fit vs fit_transform
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (4000, 3) (1000, 3) (4000,) (1000,)

# %% [markdown]
# ## **Implimenting Linear regression**

# %%
#Importing the required libraries
from sklearn.linear_model import LinearRegression
ml = LinearRegression() #creating an object of LinearRegression class
ml.fit(x_train,y_train) # fitting the training data
y_pred=ml.predict(x_train)
print(' r2 score for Training :',r2_score(y_train,y_pred)) #print of r2 score for train
print('Mean Squared Error for Training: ',mean_squared_error(y_train,y_pred))  #Print MSE value for train
print('Root Mean Squared Error for Training: ',np.sqrt(mean_squared_error(y_train,y_pred)))  #Print RMSE value for train
print('----------------------------------------------')

Y_test_pred=ml.predict(x_test) #prediction of y_test
print(' r2 score for Testing :',r2_score(y_test,Y_test_pred))#print of r2 score for test
print('Mean Squared Error for Testing: ',mean_squared_error(y_test,Y_test_pred)) #Print MSE value for test
print('Root Mean Squared Error for Testing: ',np.sqrt(mean_squared_error(y_test,Y_test_pred))) #Print RMSE value for test

plt.figure(figsize=(10, 6))
plt.scatter(y_train,y_pred)
plt.scatter(y_test,Y_test_pred)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('actual vs predicted')
# Out:
#  r2 score for Training : 0.6404080906219295
# Mean Squared Error for Training:  214662384.86551794
# Root Mean Squared Error for Training:  14651.361194971543
# ----------------------------------------------
#  r2 score for Testing : 0.6331508337807857
# Mean Squared Error for Testing:  218787265.08648717
# Root Mean Squared Error for Testing:  14791.459193956733
# Text(0.5, 1.0, 'actual vs predicted')

# %% [markdown]
# **r2 score for Training : 0.64**
#
# Mean Squared Error for Training:  214662384
#
#
# Root Mean Squared Error for Training:  14651
#
#
# **r2 score for Testing : 0.64**
#
# Mean Squared Error for Testing:  218787265
#
# Root Mean Squared Error for Testing:   14791

# %%
#Repeated Random Test_Train splits cross validation
#Importing KFold from sklearn model
from sklearn.model_selection import ShuffleSplit
model=LinearRegression()
shs=ShuffleSplit(n_splits=10,test_size=0.20)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=shs)
print(results)
print(np.mean(results))
# Out:
# [0.65940706 0.6052272  0.65214446 0.62606778 0.63570309 0.61156716
#  0.60332487 0.63080192 0.6102249  0.62989028]
# 0.6264358707682077

# %% [markdown]
#  # **Conclussion:**
#
#  **From all the regression models, Comparitively Rondom-Forest-Regression algorithm has giving very low RMSC and Very Good Accuracy**
#
#
# *   **Root mean square error: 107**
# *   **Acuuracy/ r2_score :     99**

# %% [markdown]
# **Acc. to Randon forest model these Important features:**
#
# *   **Education**   - Educational background of an employee.
# *   **Total sales** - total sales made by the person.
# *   **Unit sales**  - unit sale made by the person.
# *   **Bonus**       - amount received by a person as bonus for sales.
# *   **Low**         - lowest balance allotted to a person.

# %% [markdown]
# *  ###  **Above features are most Important features**
# *  ###  **Salary is varying with respect to the facters-->Education(Gradution & post graduation), Total sales, Unit sales, Low.**
# *  ###  **HR must consider these features to offer salary to new and existing people for hike.**
